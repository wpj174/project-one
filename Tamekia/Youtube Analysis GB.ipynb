# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#save file path to Variable 
File ="GB_Merged_data.csv"

#Read the CSV into Pandas Dataframe 
youtube_df = pd.read_csv(File) 

#"US_youtube_trending_data.csv")

youtube_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0     video_id                                              title  \
# 0           0  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 1           1  kgUV1MaD_M8                     Nines - Clout (Official Video)
# 2           2  ZNfeMbO_AHo  Popek ft. Dr Alban - It's My Life  (prod. Clay...
# 3           3  p7HGUZWq_8s                          Doing Doja Cat’s Makeup!!
# 4           4  vBpKlwm64SI  MANCHESTER UNITED vs FC COPENHAGEN With MARK G...
#
#             publishedAt                 channelId      channelTitle  \
# 0  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g     jacksepticeye
# 1  2020-08-10T18:30:28Z  UCvDkzrj8ZPlBqRd6fIxdhTw             Nines
# 2  2020-08-12T10:00:09Z  UC8Mh9UmrIaQPEcybdWvQsOg     KrólAlbaniiTV
# 3  2020-08-11T19:00:09Z  UCucot-Zp428OwkyRm2I7v2Q     James Charles
# 4  2020-08-10T22:08:11Z  UCMmVPVb0BwSIOWVeDwlPocQ  The United Stand
#
#    categoryId         trending_date  \
# 0          24  2020-08-12T00:00:00Z
# 1          24  2020-08-12T00:00:00Z
# 2          24  2020-08-12T00:00:00Z
# 3          24  2020-08-12T00:00:00Z
# 4          24  2020-08-12T00:00:00Z
#
#                                                 tags  view_count     likes  \
# 0  jacksepticeye|funny|funny meme|memes|jacksepti...   2038853.0  353790.0
# 1  Nines|Trapper of the year|Crop Circle|Nines Tr...    613785.0   37567.0
# 2                                             [None]    277506.0   27420.0
# 3  james|james charles|makeup artist|covergirl|co...   3662673.0  394697.0
# 4  The United Stand|United Stand|United|Mark Gold...    570490.0    8737.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0    2628.0        40228.0  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 1     669.0         2101.0  https://i.ytimg.com/vi/kgUV1MaD_M8/default.jpg
# 2     617.0         1268.0  https://i.ytimg.com/vi/ZNfeMbO_AHo/default.jpg
# 3    5760.0        27349.0  https://i.ytimg.com/vi/p7HGUZWq_8s/default.jpg
# 4     460.0          269.0  https://i.ytimg.com/vi/vBpKlwm64SI/default.jpg
#
#   comments_disabled ratings_disabled  \
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False
#
#                                          description   categoryName
# 0  I left youtube for a month and this is what ha...  Entertainment
# 1  Nines - Clout (Official Video)Listen to Clout ...  Entertainment
# 2  Nowa wersja kultowego utworu z lat 90’.Posłuch...  Entertainment
# 3  HI SISTERS! Today’s video is a collaboration w...  Entertainment
# 4  Manchester United vs FC Copenhagen Match React...  Entertainment

# %%
df_cleaned = youtube_df[['video_id','view_count','likes','dislikes','comment_count','trending_date','categoryId','categoryName']].sort_values(['video_id','trending_date','view_count'],ascending=False).drop_duplicates(subset="video_id")
df_cleaned.head()
# Out:
#           video_id  view_count     likes  dislikes  comment_count  \
# 67239  zzxPZwaA-8w   2144129.0   32744.0     823.0         2037.0
# 48169  zzd4ydafGR0  11713353.0  689948.0    6979.0        55541.0
# 61322  zzYaFc8nzQM   1046055.0   62315.0    1150.0         2157.0
# 17744  zyg837Y0PHA    318294.0   17388.0     134.0          620.0
# 71337  zyTqElwSG5w   1221657.0   28476.0     815.0          949.0
#
#               trending_date  categoryId   categoryName
# 67239  2021-05-30T00:00:00Z          17         Sports
# 48169  2021-02-19T00:00:00Z          10          Music
# 61322  2020-12-05T00:00:00Z          17         Sports
# 17744  2021-08-21T00:00:00Z          24  Entertainment
# 71337  2021-08-29T00:00:00Z          17         Sports

# %%
# Rename the headers to be more explanatory
renamed_df = df_cleaned.rename(columns={"video_id": "Video ID",
                                        "view_count": "View Count",
                                        "likes":"Likes",
                                        "dislikes": "Dislikes",
                                        "comment_count": "Comment Count",
                                        "trending_date": "Trending Date",
                                        "categoryId": "Category ID",
                                        "categoryName": "Category Name",})
renamed_df.head()
# Out:
#           Video ID  View Count     Likes  Dislikes  Comment Count  \
# 67239  zzxPZwaA-8w   2144129.0   32744.0     823.0         2037.0
# 48169  zzd4ydafGR0  11713353.0  689948.0    6979.0        55541.0
# 61322  zzYaFc8nzQM   1046055.0   62315.0    1150.0         2157.0
# 17744  zyg837Y0PHA    318294.0   17388.0     134.0          620.0
# 71337  zyTqElwSG5w   1221657.0   28476.0     815.0          949.0
#
#               Trending Date  Category ID  Category Name
# 67239  2021-05-30T00:00:00Z           17         Sports
# 48169  2021-02-19T00:00:00Z           10          Music
# 61322  2020-12-05T00:00:00Z           17         Sports
# 17744  2021-08-21T00:00:00Z           24  Entertainment
# 71337  2021-08-29T00:00:00Z           17         Sports

# %%
renamed_df.to_csv("NewUS_clean.csv",
    encoding="utf-8", index=False,header=True)

# %%
categoryGroup = renamed_df.groupby(["Category Name"])


categorySum_df=categoryGroup.sum()

categorySum_df.head()
# Out:
#                     View Count        Likes    Dislikes  Comment Count  \
# Category Name
# Autos & Vehicles  4.065066e+08   16625522.0    314123.0      1337544.0
# Comedy            1.780955e+09  101131843.0   2215682.0      5521380.0
# Education         7.515574e+08   35792544.0    761854.0      2415545.0
# Entertainment     1.017995e+10  484774263.0  10933280.0     31551735.0
# Film & Animation  1.117759e+09   47772688.0   1076444.0      3704296.0
#
#                   Category ID
# Category Name
# Autos & Vehicles          632
# Comedy                  18515
# Education                8883
# Entertainment           89856
# Film & Animation          420

# %%
vc_total=df_cleaned.groupby(["view_count"])
vc_total_df= pd.DataFrame(renamed_df.sum(),columns=['Values'])
vc_total_df = vc_total_df.drop(index=['Category ID', 'Category Name'])
vc_total_df
# Out:
#                       Values
# View Count     43803573671.0
# Likes           2199517798.0
# Dislikes          49675610.0
# Comment Count    192773068.0

# %%
viewcount=df_cleaned.groupby(["view_count"])
viewcount_df= pd.DataFrame(renamed_df.sum(),columns=['Values'])
viewcount_df = vc_total_df.drop(index=['Comment Count'])
viewcount_df
# Out:
#                    Values
# View Count  43803573671.0
# Likes        2199517798.0
# Dislikes       49675610.0

# %%
plt.bar(viewcount_df.index.values,viewcount_df['Values'],color="Green")

plt.ylabel("")
plt.xlabel("")
plt.title("Total Views v Likes vs Dislikes ")
#plt.grid()
plt.show()

# %%
comments=df_cleaned.groupby(["comment_count"])
comments_df= pd.DataFrame(renamed_df.sum(),columns=['Values'])
comments_df = vc_total_df.drop(index=['View Count'])
comments_df
# Out:
#                      Values
# Likes          2199517798.0
# Dislikes         49675610.0
# Comment Count   192773068.0

# %%
plt.bar(comments_df.index.values,comments_df['Values'],color="Green")

plt.ylabel("")
plt.xlabel("")
plt.title("Comment Count v Likes vs Dislikes ")
#plt.grid()
plt.show()

# %%
plt.bar(vc_total_df.index.values,vc_total_df['Values'],color="Green")

plt.ylabel("")
plt.xlabel("")
plt.title("Total Number of Likes vs Dislikes and Comment Count ")
#plt.grid()
plt.show()

# %%
plt.bar(categorySum_df.index.values,categorySum_df["Likes"], color="red")
plt.ylabel("Number of Likes ")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.title("Trending Videos Likes by Category ")
#plt.grid()
#plt.ylim([0,])
plt.show()

# %%
plt.bar(categorySum_df.index.values,categorySum_df["Dislikes"], color="Blue")
plt.ylabel("Number of Dislikes")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.title("Trending Videos Dislikes by Category")
#plt.grid()
#plt.ylim([0,])
plt.show()

# %%
plt.bar(categorySum_df.index.values,categorySum_df["Comment Count"], color="Green")
plt.ylabel("")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.title("Trending Videos Comment Count by Category")
#plt.grid()
#plt.ylim([0,])
plt.show()

# %%
y =categorySum_df['View Count'] 
x =categorySum_df['Likes']

# %%
plt.figure(figsize = (15,7))
# plt.scatter(x,y,c=categorySum_df.index.values)
#plt.scatter(x, y, marker="o", facecolors="red", edgecolors="black"
#           )
for ticker,row in categorySum_df.iterrows():
  plt.scatter(row['View Count'], row['Likes'], label=ticker, s=100)
plt.xlabel("")
plt.ylabel("Max Likes per Category")
plt.legend(loc='best')
    
plt.show()

# %%
y =categorySum_df['View Count']
x =categorySum_df['Dislikes']

# %%
plt.figure(figsize = (15,7))
for ticker,row in categorySum_df.iterrows():
  plt.scatter(row['View Count'], row['Dislikes'], label=ticker, s=100)
plt.xlabel("Max View Count")
plt.ylabel("Max Dislikes")
plt.legend(loc='best')
    
plt.show()

# %%
h_labels = [x.replace('_', ' ').title() for x in 
            list(categorySum_df.select_dtypes(include=['number', 'bool']).columns.values)]

fig, ax = plt.subplots(figsize=(15,7))
_ = sns.heatmap(categorySum_df.corr(), annot=True, xticklabels=h_labels, yticklabels=h_labels, cmap=sns.cubehelix_palette(start=2.8, rot=.1))

ax.set_title('Great Britain')

#Youtube Trending video analysis:

#This shows how and if the variables in a dataset correlate/relationship with one another.The table on the right show has a scale of 
 #  0.4being the lowest correlation  to 1.0 being the strongest correlation to another. We can see that views and likes  are strongly correlated to one another.
# Out:
# Text(0.5, 1.0, 'Great Britain')

# %%
y1 =categorySum_df['Likes']
y2 =categorySum_df['Dislikes']

x=categorySum_df.index.values
  
# plot bars in stack manner
plt.figure(figsize = (15,7))
plt.xticks(rotation=90)
b1 = plt.barh(x,y1, color="green")
b2 = plt.barh(x, y2, left=y1, color="red")
plt.legend([b1, b2], ["Likes", "Dislikes"], title="Interaction", loc="upper right")
